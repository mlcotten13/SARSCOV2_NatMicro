# %%
### import numpy as np 
import pandas as pd
from pandas import DataFrame
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np
from collections import defaultdict
from matplotlib.colors import rgb2hex, colorConverter
from datetime import time
import matplotlib as mpl

import numpy.random as rnd
from matplotlib import cm

mpl.rcParams['figure.dpi']= 300

# %%
##### Import data
outprefix = "cases_vs_genomes"
this_font_scale=0.1
df1 = pd.read_csv('case_vs_genome_gr100.csv', sep=",", na_values=['-'])
# df_complete = pd.concat([df1,df2,df3,df4,df5,df6])
df_complete = df1
df_complete.head()
# Out:
#   District  Total_cases  Perc_cases  Genome_count  Perc_genomes
# 0  Kampala        16398   56.255789           150     44.378698
# 1   Wakiso         2907    9.972898            17      5.029586
# 2   Luwero          739    2.535250             4      1.183432
# 3    Amuru          728    2.497513            21      6.213018
# 4  Mbarara          664    2.277951             1      0.295858

# %%
df_complete['District'].value_counts()
# Out:
# Mukono         1
# Mbarara        1
# Tororo         1
# Amuru          1
# Arua           1
# Luwero         1
# Butaleja       1
# Kiryandongo    1
# Kabale         1
# Pader          1
# Wakiso         1
# Lira           1
# Jinja          1
# Soroti         1
# Masaka         1
# Moroto         1
# Kabarole       1
# Kikuube        1
# Mbale          1
# Kyotera        1
# Namisindwa     1
# Kampala        1
# Kasese         1
# Buikwe         1
# Gulu           1
# Kitgum         1
# Name: District, dtype: int64

# %%
many = ["#485690","#a2d7dd", "#b00149","#5c9291","#ee7948","#008899","#fcd575","#59b9c6", "#e2041b","#4d5aaf","#ec6d71","#a8bf93","#38b48b","#95949a","#0485d1","#fd3c06","#c8c2be","#6c848d","#ed6d3d","#393f4c","#5c9291","#00035b","#fd3c06","#748b97","#06b48b"]
sns.palplot(sns.color_palette(many))

# %%
# df=pd.DataFrame(data,columns=["Name","Age","Height(cm)","Weight(kg)"])
df_complete.plot(x="District", y=["Perc_cases", "Perc_genomes"], kind="bar",figsize=(8,3),color=many, log = "true")
# plt.show()

plt.savefig(outprefix+'_cases_genomes.pdf',bbox_inches="tight")
plt.savefig(outprefix+'_cases_genomes.jpg',bbox_inches="tight", dpi=300)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-67980149235c> in <module>
#       2 df_complete.plot(x="District", y=["Perc_cases", "Perc_genomes"], kind="bar",figsize=(8,3),color=many, log = "true")
#       3 # plt.show()
# ----> 4 plt.set_ylabel("log percentage")
#       5 plt.savefig(outprefix+'_cases_genomes.pdf',bbox_inches="tight")
#       6 plt.savefig(outprefix+'_cases_genomes.jpg',bbox_inches="tight", dpi=300)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_ylabel'
